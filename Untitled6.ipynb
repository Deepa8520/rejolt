# %%
import pandas as p
import numpy as np

# %%
d=p.read_csv("SalaryPrediction.csv")
d.head
print(d.isnull())
# Out:
#        Wage    Age   Club  League  Nation  Position   Apps   Caps
# 0     False  False  False   False   False     False  False  False
# 1     False  False  False   False   False     False  False  False
# 2     False  False  False   False   False     False  False  False
# 3     False  False  False   False   False     False  False  False
# 4     False  False  False   False   False     False  False  False
# ...     ...    ...    ...     ...     ...       ...    ...    ...
# 3902  False  False  False   False   False     False  False  False
# 3903  False  False  False   False   False     False  False  False
# 3904  False  False  False   False   False     False  False  False
# 3905  False  False  False   False   False     False  False  False
# 3906  False  False  False   False   False     False  False  False
#
# [3907 rows x 8 columns]

# %%
d.sample(6)
# Out:
#            Wage  Age            Club             League Nation    Position  \
# 1820    483,000   22          Empoli            Serie A    ITA     Forward
# 863   1,820,000   23       AS Monaco  Ligue 1 Uber Eats    FRA    Defender
# 85    9,100,000   32        Man City     Premier League    ENG    Defender
# 962   1,560,000   31    Nottm Forest     Premier League    ENG    Defender
# 2750    104,000   18        Brighton     Premier League    SWE    Defender
# 3182     47,000   18  Crystal Palace     Premier League    ENG  Goalkeeper
#
#       Apps  Caps
# 1820   104     0
# 863    132     0
# 85     400    68
# 962    403     0
# 2750     0     0
# 3182     0     0

# %%
d.isnull().sum()
a=d.isnull()

# %%
d.dropna()
# Out:
#             Wage  Age       Club             League Nation    Position  Apps  \
# 0     46,427,000   23        PSG  Ligue 1 Uber Eats    FRA     Forward   190
# 1     42,125,000   30        PSG  Ligue 1 Uber Eats    BRA   Midfilder   324
# 2     34,821,000   35        PSG  Ligue 1 Uber Eats    ARG     Forward   585
# 3     19,959,000   31  R. Madrid            La Liga    BEL     Forward   443
# 4     19,500,000   31    Man UFC     Premier League    ESP  Goalkeeper   480
# ...          ...  ...        ...                ...    ...         ...   ...
# 3902       3,400   19       Vigo            La Liga    ESP    Defender     0
# 3903       3,200   18  Famalicao      Primiera Liga    BRA  Goalkeeper     0
# 3904       2,900   18       Vigo            La Liga    ESP     Forward     0
# 3905       2,700   18       Vigo            La Liga    ESP    Defender     0
# 3906       1,400   18       Vigo            La Liga    ESP    Defender     0
#
#       Caps
# 0       57
# 1      119
# ...

# %%
total = np.product(d.shape)
t_missing= a.sum()

(t_missing/total) * 100
# Out:
# Wage        0.0
# Age         0.0
# Club        0.0
# League      0.0
# Nation      0.0
# Position    0.0
# Apps        0.0
# Caps        0.0
# dtype: float64

# %%
d.fillna(method = 'bfill', axis=0).fillna(0)
# Out:
#             Wage  Age       Club             League Nation    Position  Apps  \
# 0     46,427,000   23        PSG  Ligue 1 Uber Eats    FRA     Forward   190
# 1     42,125,000   30        PSG  Ligue 1 Uber Eats    BRA   Midfilder   324
# 2     34,821,000   35        PSG  Ligue 1 Uber Eats    ARG     Forward   585
# 3     19,959,000   31  R. Madrid            La Liga    BEL     Forward   443
# 4     19,500,000   31    Man UFC     Premier League    ESP  Goalkeeper   480
# ...          ...  ...        ...                ...    ...         ...   ...
# 3902       3,400   19       Vigo            La Liga    ESP    Defender     0
# 3903       3,200   18  Famalicao      Primiera Liga    BRA  Goalkeeper     0
# 3904       2,900   18       Vigo            La Liga    ESP     Forward     0
# 3905       2,700   18       Vigo            La Liga    ESP    Defender     0
# 3906       1,400   18       Vigo            La Liga    ESP    Defender     0
#
#       Caps
# 0       57
# 1      119
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['League'].value_counts()
    for x_label, grp in _df_33.groupby('Club')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Club')
_ = plt.ylabel('League')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_23.groupby('Wage').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_20['Age'].plot(kind='hist', bins=20, title='Age')
plt.gca().spines[['top', 'right',]].set_visible(False)
